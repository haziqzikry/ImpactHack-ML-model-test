# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Load the data
data = pd.read_csv('Sales_April_2019.csv')
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
#remove duplicates
data.drop_duplicates(inplace=True)

# %%
#remove null values
data.dropna(inplace=True)
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
data.shape
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18268 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18268 non-null  object
#  1   Product           18268 non-null  object
#  2   Quantity Ordered  18268 non-null  object
#  3   Price Each        18268 non-null  object
#  4   Order Date        18268 non-null  object
#  5   Purchase Address  18268 non-null  object
# dtypes: object(6)
# memory usage: 999.0+ KB

# %%
import pandas as pd

# Load the data and skip the first row
data = pd.read_csv('Sales_April_2019.csv', skiprows=1)

# Rename the columns if necessary
data.rename(columns={'Order Date': 'Order_Date'}, inplace=True)  # Replace 'Order_Date' with the actual column name

# Data preprocessing
data['Order_Date'] = pd.to_datetime(data['Order_Date'], format='%m/%d/%y %H:%M')  # Replace 'Order_Date' with the actual column name

# Extract month and year from Order Date
data['Month'] = data['Order_Date'].dt.month
data['Year'] = data['Order_Date'].dt.year

# Filter data for the next month
current_month = data['Month'].max()
current_year = data['Year'].max()

next_month_data = data[(data['Month'] == current_month + 1) & (data['Year'] == current_year)]

# Predict the most popular product for the next month
most_popular_product = next_month_data['Product'].value_counts().idxmax()

print("Predicted most popular product for the next month:", most_popular_product)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HaziqZikry-T14\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\HaziqZikry-T14\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\HaziqZikry-T14\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Order_Date'
#
# The above exception was the direct cause of the following exception:
#
# ...
