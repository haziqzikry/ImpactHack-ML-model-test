# %%
import pandas as pd
import json

# %%
with open('new_inventory_data.json') as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data)
df
# Out:
#     Product type   SKU  Price  Availability  Number of products sold  \
# 0         Sports  7841  90.55      In Stock                       55
# 1           Home  9799  97.13  Out of Stock                       82
# 2         Sports  7732  51.78  Out of Stock                       29
# 3         Sports  1205  98.01      In Stock                       84
# 4       Clothing  4407  55.64  Out of Stock                       10
# ..           ...   ...    ...           ...                      ...
# 295     Clothing  1469  40.99  Out of Stock                       21
# 296     Clothing  7958  66.03      In Stock                       72
# 297       Sports  7089  25.88      In Stock                       94
# 298         Home  8383  61.82      In Stock                       13
# 299         Home  3059  94.34      In Stock                       79
#
#      Revenue generated Customer demographics  Stock levels  Lead times  \
# ...

# %%
df_filtered = df[df['Order d'] == 0]
df_filtered
